# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import bottleneck as bn

from astropy.nddata import CCDData
from astropy.stats import sigma_clipped_stats
from astropy.coordinates import SkyCoord
from astropy.table import Table, Column, vstack
from astropy.visualization import hist
from astropy import units as u
from astropy.time import Time

from ccdproc import combine, ImageFileCollection

import reproject

from photutils import DAOStarFinder, CircularAperture, CircularAnnulus, aperture_photometry, centroid_sources

from astrowidgets import ImageWidget

# %% [markdown]
# ## The image viewer widget is optional...

# %%
iw = ImageWidget()
iw
# Out:
# ImageWidget(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\x…

# %%
iw.load_fits('kelt-16-S001-R001-C100-r.fit')
#iw.load_fits('kelt-16-b-S001-R001-C130-r.fit')
# Out:
# WARNING: VerifyWarning: Keyword name 'TRIM_IMAGE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'SUBTRACT_BIAS' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'SUBTRACT_DARK' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'FLAT_CORRECT' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]

# %%
iw.center_on(SkyCoord(313.92459686592696, 31.78329193408578, unit='degree'), pixel_coords_offset=0)

# %%
iw.center_on(SkyCoord.from_name('kelt-16'))

# %% [markdown]
# # Required stuff starts here

# %% [markdown]
# ## Read one image to use detect sources
#
# This could be any image; I chose one roughly in the middle of the sequence. Ideally maybe we'd choose sources that were only in all of the images, but this will work for now.

# %%
ccd = CCDData.read('kelt-16-S001-R001-C100-r.fit')
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / Equatorial coordinate system
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]

# %%
def faster_sigma_clip_stats(data, sigma=5, iters=5, axis=None):
    data = data.copy()
    for _ in range(iters):
        central = bn.nanmedian(data, axis=axis)
        try:
            central = central[:, np.newaxis]
        except (ValueError, IndexError):
            pass
                
        std_dif = 1.4826 * bn.nanmedian(np.abs(data - central))
        clips = np.abs(data - central) / std_dif > sigma
        if clips.sum() == 0:
            break
        data[clips] = np.nan
    return bn.nanmean(data, axis=axis), bn.nanmedian(data, axis=axis), bn.nanstd(data, axis=axis)

# %% [markdown]
# The background light from the sky needs to be removed before looking for sources. We'll do that by calculating the median. "Sigma clipping" is the term for excluding data that is far from the average...here we do it mostly to exclude the "bright" pixels (i.e. the stars) from our estimate of the background.

# %%
men, med, std = faster_sigma_clip_stats(ccd.data, sigma=5)
men, med, std
# Out:
# C:\Anaconda3\envs\ast366\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in greater
#   # This is added back by InteractiveShellApp.init_path()
# C:\Anaconda3\envs\ast366\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in greater
#   # This is added back by InteractiveShellApp.init_path()
# C:\Anaconda3\envs\ast366\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in greater
#   # This is added back by InteractiveShellApp.init_path()
# (21.55644, 21.191854, 8.735692)

# %% [markdown]
# This sets up the source detection. The FWHM turns out to be key...making it too small results in a single star being detected as two separate sources.
#
# Stars must be brighter than the threshold to count as sources. Making the number higher gives you fewer detected sources, lower gives you more. There is no "magic" number.

# %%
dao = DAOStarFinder(threshold=10 * std, fwhm=8, exclude_border=True)

# %% [markdown]
# Actually detect the stars...

# %%
stars = dao(ccd - med)

# %% [markdown]
# ## Only include this if you have an image viewer above
#
# It is handy to see where the detected sources are....

# %%
iw.reset_markers()
iw.marker = {'type': 'circle', 'color': 'lightgreen', 'radius': 10}
iw.add_markers(stars, x_colname='xcentroid', y_colname='ycentroid', pixel_coords_offset=0)

# %% [markdown]
# ## Pick aperture and annulus sizes
#
# Probably the best way to do this for now is to upload one of the kelt-16 images to the notebook we used in class to plot star profiles. You want an aperture about 2×FWHM, an annulus with  an inner radius at least 10 pixels larger than that, and outer radius about 15 pixels larger than the inner.

# %%
aperture_rad = 12
inner_annulus = aperture_rad + 15
outer_annulus = inner_annulus + 15

# %% [markdown]
# Set up the aperture objects used later by photutils to do the photometry.

# %%
aps = CircularAperture([stars['xcentroid'], stars['ycentroid']], r=aperture_rad)
anuls = CircularAnnulus([stars['xcentroid'], stars['ycentroid']], inner_annulus, outer_annulus)

# %% [markdown]
# ## Set pixels that are above point where CCD becomes non-linear to invalid value
#
# This will ensure that the aperture sum is an invalid value if one or more of the pixels in the aperture is non-linear. *Change the value below to what you think is appropriate -- I'm going from memory.*

# %%
max_adu = 45000
ccd.data[ccd.data > max_adu] = np.nan

# %% [markdown]
# ## Set up sky coordinates of target list
#
# We'll want to the list of stars in RA/Dec so we can find them in each image.
#
# `star_locs` is waht is used later on to place the apertures

# %%
star_locs = ccd.wcs.all_pix2world(stars['xcentroid'], stars['ycentroid'], 0)

# %% [markdown]
# ### Check for stars closer than 2 × aperture radius and remove from list

# %%
star_coords = SkyCoord(ra=star_locs[0], dec=star_locs[1], frame='icrs', unit='degree')

# %%
idxc, d2d, d3d = star_coords.match_to_catalog_sky(star_coords, nthneighbor=2)

# %%
d2d.min()
# Out:
# <Angle 0.00082005 deg>

# %%
too_close = d2d < (aperture_rad * 2 * 0.563 * u.arcsec)

# %% [markdown]
# ### Include this only if you have the image viewer -- it shows which stars are being removed

# %%
iw.marker = {'type': 'circle', 'color': 'red', 'radius': 20}
iw.add_markers(stars[too_close], x_colname='xcentroid', y_colname='ycentroid', pixel_coords_offset=0)

# %%
star_locs = (star_locs[0][~too_close], star_locs[1][~too_close])

# %% [markdown]
# ### Make up a unique ID for each star

# %%
star_ids = np.arange(len(star_locs[0])) + 1

# %% [markdown]
# ## Define a couple of convenience functions

# %% [markdown]
# ### Calculate average pixel values in annulus, rejecting extreme values

# %%
def clipped_sky_per_pix_stats(data, annulus, sigma=5, iters=5):
    # Get a list of masks from the annuli
    # Use the 'center' method because then pixels are either in or out. To use
    # 'partial' or 'exact' we would need to do a weighted sigma clip and I'm not sure 
    # how to do that.
    masks = annulus.to_mask(method='center')
    
    anul_list = []
    for mask in masks:
        # Multiply the mask times the data
        to_clip = mask.multiply(data.data, fill_value=np.nan)
        anul_list.append(to_clip.flatten())
    # Convert the list to an array for doing the sigma clip
    anul_array = np.array(anul_list)
    # Turn all zeros into np.nan...
    anul_array[anul_array == 0] = np.nan
    avg_sky_per_pix, med_sky_per_pix, std_sky_per_pix = faster_sigma_clip_stats(anul_array, 
                                                                                sigma=sigma, 
                                                                                iters=iters,
                                                                                axis=1
                                                                               )

    return (avg_sky_per_pix * data.unit, med_sky_per_pix * data.unit, std_sky_per_pix * data.unit)

# %% [markdown]
# ### Add more columns to the data table

# %%
def add_to_photometry_table(phot, ccd, annulus, apertures, fname='', 
                            star_ids=None, gain=None):
    phot.rename_column('aperture_sum_0', 'aperture_sum')
    phot['aperture_sum'].unit = u.adu
    phot.rename_column('aperture_sum_1', 'annulus_sum')
    star_locs = ccd.wcs.all_pix2world(phot['xcenter'], phot['ycenter'], 0)
    star_coords = SkyCoord(ra=star_locs[0], dec=star_locs[1], frame='icrs', unit='degree')
    phot['RA'] = star_coords.ra
    phot['Dec'] = star_coords.dec
    print('        ...calculating clipped sky stats')
    avg_sky_per_pix, med_sky_per_pix, std_sky_per_pix = clipped_sky_per_pix_stats(ccd, annulus)
    print('        ...DONE calculating clipp sky stats')
    phot['sky_per_pix_avg'] = avg_sky_per_pix
    phot['sky_per_pix_med'] = med_sky_per_pix
    phot['sky_per_pix_std'] = std_sky_per_pix
    phot['aperture'] = apertures.r * u.pixel
    phot['aperture_area'] = apertures.area() # * u.pixel * u.pixel
    phot['annulus_inner'] = annulus.r_in * u.pixel
    phot['annulus_outer'] = annulus.r_out * u.pixel
    phot['annulus_area'] = annulus.area() #* u.pixel * u.pixel
    phot['exposure'] = [ccd.header['exposure']] * len(phot) * u.second
    phot['date-obs'] = [ccd.header['DATE-OBS']] * len(phot)
    night = Time(ccd.header['DATE-OBS'], scale='utc')
    night.format = 'mjd'
    phot['night'] = np.int(np.floor(night.value - 0.5))
    phot['aperture_net_flux'] = phot['aperture_sum'] - phot['aperture_area'] * phot['sky_per_pix_avg']
    
    if gain is not None:
        phot['mag_inst_{}'.format(ccd.header['filter'])] = -2.5 * np.log10(gain * phot['aperture_net_flux'].value / phot['exposure'].value)

    metadata_to_add = ['AIRMASS', 'FILTER']
    for meta in metadata_to_add:
        phot[meta.lower()] = [ccd.header[meta]] * len(phot)    
    if fname:
        phot['file'] = fname
    if star_ids is not None:
        phot['star_id'] = star_ids

# %% [markdown]
# ## We are ready to do photometry on all of the images
#
# ### Get the images in this folder...

# %%
ifc = ImageFileCollection('.')

# %% [markdown]
# ### Loop over all images and do photometry on them.
#
# + Change the object name if you need to.
# + If there are images you want to skip put them in a different folder

# %%
phots = []
missing_stars = []
for a_ccd, fname in ifc.ccds(object='kelt-16b', return_fname=True):
    print('on image ', fname)
    # Convert RA/Dec to pixel coordinates for this image
    pix_coords = a_ccd.wcs.all_world2pix(star_locs[0], star_locs[1], 0)
    xs, ys = pix_coords
    
    # Remove anything that is too close to the edges/out of frame
    padding = 3 * aperture_rad
    out_of_bounds = (xs < padding) | (xs > (a_ccd.shape[0] - padding)) | (ys < padding) | (ys > (a_ccd.shape[1] - padding))
    in_bounds = ~out_of_bounds
    
    # Find centroids of each region around star that is in_bounds
    xs_in = xs[in_bounds]
    ys_in = ys[in_bounds]
    print('    ...finding centroids')
    xcen, ycen = centroid_sources(a_ccd.data, xs_in, ys_in, box_size=2 * aperture_rad + 1)

    # Calculate offset between centroid in this image and the positions based on 
    # input RA/Dec. Later we wil set the magnitude of those with large differences
    # to an invalid value (maybe).
    center_diff = np.sqrt((xs_in - xcen)**2 + (ys_in - ycen)**2)

    #Set up apertures and annuli based on the centroids in this image.
    aps = CircularAperture((xcen, ycen), r=aperture_rad)
    anuls = CircularAnnulus((xcen, ycen), inner_annulus, outer_annulus)

    # Set any clearly bad values to NaN
    a_ccd.data[a_ccd.data > max_adu] = np.nan
    print('    ...doing photometry')
    # Do the photometry...
    pho = aperture_photometry(a_ccd.data, (aps, anuls), mask=a_ccd.mask, method='center')

    # We may have some stars we did not do photometry for because those stars were out of bounds.
    # Add the ones we missed to the list of missing
    missed = star_ids[out_of_bounds]
    missing_stars.append(missed)

    # Add all the extra goodies to the table
    print('    ...adding extra columns')
    add_to_photometry_table(pho, a_ccd, anuls, aps, fname=fname, star_ids=star_ids[in_bounds],
                            gain=1.47)
    # And add the final table to the list of tables
    phots.append(pho)
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / Equatorial coordinate system
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / Equatorial coordinate system
# the RADECSYS keyword is deprecated, use RADESYSa.
# on image  kelt-16-S001-R001-C001-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
# C:\Anaconda3\envs\ast366\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in greater
#   # This is added back by InteractiveShellApp.init_path()
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C002-r.fit
#     ...finding centroids
# C:\Anaconda3\envs\ast366\lib\site-packages\ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in log10
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C003-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C004-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C005-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C006-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C007-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C008-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C009-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C010-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C011-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C012-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C013-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C014-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C015-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C016-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C017-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C018-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C019-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C020-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C021-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C022-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C023-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C024-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C025-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C026-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C027-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C028-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C029-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C030-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C031-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C032-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C033-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C034-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C035-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C036-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C037-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C038-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C039-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C040-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C041-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C042-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C043-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C044-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C045-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C046-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C047-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C048-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C049-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C050-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C051-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C052-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C053-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C054-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C055-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C056-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C057-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C058-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C059-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C060-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C061-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C062-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C063-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C064-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C065-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C066-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C067-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C068-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C069-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C070-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C071-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C072-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C073-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C074-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C075-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C076-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C077-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C078-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C079-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C080-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C081-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C082-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C083-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C084-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C085-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C086-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C087-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C088-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C089-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C090-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C091-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C092-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C093-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C094-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C095-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C096-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C097-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C098-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C099-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C100-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C101-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C102-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C103-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C104-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C105-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C106-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C107-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C108-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C109-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C110-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C111-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C112-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C113-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C114-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C115-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C116-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C117-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C118-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C119-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C120-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C121-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C122-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C123-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C124-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C125-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C126-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C127-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C128-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C129-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C130-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C131-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C132-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C133-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C134-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C135-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C136-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C137-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C138-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C139-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C140-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C141-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C142-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C143-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C144-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C145-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C146-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C147-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C148-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C149-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C150-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C151-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C152-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C153-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C154-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C155-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C156-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C157-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C158-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C159-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C160-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C161-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C162-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C163-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C164-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C165-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats
# on image  kelt-16-S001-R001-C166-r.fit
#     ...finding centroids
#     ...doing photometry
#     ...adding extra columns
#         ...calculating clipped sky stats
#         ...DONE calculating clipp sky stats

# %% [markdown]
# ### Combine all of the individual photometry tables into one

# %%
all_phot = vstack(phots)

# %% [markdown]
# ### Eliminate any stars that are missing from one or more images
#
# This makes life a little easier later...

# %%
uniques = set()
for miss in missing_stars:
    uniques.update(set(miss))

actually_bad = sorted([u for u in uniques if u in all_phot['star_id']])
len(uniques), len(actually_bad)
# Out:
# (147, 144)

# %%
all_phot.add_index('star_id')
bad_rows = all_phot.loc_indices[actually_bad]

# %%
all_phot.remove_indices('star_id')
all_phot.remove_rows(sorted(bad_rows))

# %% [markdown]
# ### Write out the file!

# %%
all_phot
# Out:
# <QTable length=228416>
#   id       xcenter       ...             file             star_id
#              pix         ...
# int32      float64       ...            str28              int32
# ----- ------------------ ... ---------------------------- -------
#    14 3154.0652623290325 ... kelt-16-S001-R001-C001-r.fit      25
#    15 2554.7526840417163 ... kelt-16-S001-R001-C001-r.fit      26
#    16 2839.0427405315436 ... kelt-16-S001-R001-C001-r.fit      27
#    17 2920.9222395184966 ... kelt-16-S001-R001-C001-r.fit      28
#    18  2484.946540721911 ... kelt-16-S001-R001-C001-r.fit      29
#    19 1088.0836400127873 ... kelt-16-S001-R001-C001-r.fit      30
#    20  3906.074337014607 ... kelt-16-S001-R001-C001-r.fit      31
#    21  2070.926989829942 ... kelt-16-S001-R001-C001-r.fit      32
#    22  1317.687011962662 ... kelt-16-S001-R001-C001-r.fit      33
#   ...                ... ...                          ...     ...
#  1415  3284.025545693105 ... kelt-16-S001-R001-C166-r.fit    1494
#  1416  565.0141560970771 ... kelt-16-S001-R001-C166-r.fit    1495
#  1417 2213.1205011841253 ... kelt-16-S001-R001-C166-r.fit    1496
#  1418 3408.9399364514597 ... kelt-16-S001-R001-C166-r.fit    1497
#  1419 2998.9205908793924 ... kelt-16-S001-R001-C166-r.fit    1498
#  1420 1142.8823447023287 ... kelt-16-S001-R001-C166-r.fit    1499
#  1421  360.9643117462234 ... kelt-16-S001-R001-C166-r.fit    1500
#  1422  3194.987758281217 ... kelt-16-S001-R001-C166-r.fit    1501
#  1423  2344.986615706668 ... kelt-16-S001-R001-C166-r.fit    1502
#  1424  1263.920511862038 ... kelt-16-S001-R001-C166-r.fit    1503

# %%
all_phot.write('all_the_photometry.fits')
# Out:
# WARNING: VerifyWarning: Keyword name 'aperture_photometry_args' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING:astropy:VerifyWarning: Keyword name 'aperture_photometry_args' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created.

# %%
all_phot.write('all_the_photometry.csv')
